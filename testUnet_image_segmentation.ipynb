# %% [markdown]
# <a href="https://colab.research.google.com/github/fahmina1319/UNET_image_segmentation/blob/main/testUnet_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input

# %%
#convolutional block

def conv_block(inputs, num_filters):
  x = Conv2D(num_filters, 3, padding="same")(inputs)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  x = Conv2D(num_filters, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  return x

# %%
#encoder block

def encoder_block(inputs, num_filters):
  x = conv_block(inputs, num_filters)
  p = MaxPool2D ((2,2))(x)

  return x, p

# %%
#decoder block

def decoder_block(inputs, skip, num_filters):
  x = Conv2DTranspose(num_filters, (2,2), strides=2, padding="same")(inputs)
  x = Concatenate()([x, skip])
  x = conv_block(x, num_filters)

  return x

# %%
#Unet

def build_unet(input_shape):
  inputs = Input(input_shape)

  #encoder blocks
  s1, p1 = encoder_block(inputs, 64)
  s2, p2 = encoder_block(p1, 128)
  s3, p3 = encoder_block(p2, 256)
  s4, p4 = encoder_block(p3, 512)


  #bridge
  b1 = conv_block(p4, 1024)


  #decoder block

  d1 = decoder_block(b1, s4, 512)
  d2 = decoder_block(d1, s3, 256)
  d3 = decoder_block(d2, s2, 128)
  d4 = decoder_block(d3, s1, 64)

  outputs = Conv2D(1,1, padding= "same", activation ="sigmoid")(d4)

  model = Model(inputs, outputs, name="UNET")

  return model

# %%
input_shape = (256, 256, 3)
model = build_unet(input_shape)

# %%
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 64)         1792      ['input_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 256, 256, 64)         256       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 256, 256, 64)         256       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 64)         0         ['activation_11[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 128, 128, 128)        512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 128, 128, 128)        512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 128)          0         ['activation_13[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, 64, 64, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 256)          0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 512)          2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 512)          2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 512)          0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_7[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 1024)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 1024)         9438208   ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 1024)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 512)          2097664   ['activation_19[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 1024)         0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_17[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 512)          4719104   ['concatenate_1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 512)          2048      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 32, 512)          2048      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 256)          524544    ['activation_21[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_15[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate_2[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 128)        131200    ['activation_23[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'activation_13[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_3[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 128)        512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 128)        512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_transpose_4 (Conv2D  (None, 256, 256, 64)         32832     ['activation_25[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'activation_11[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_4[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 64)         256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 256, 256, 64)         256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 256, 256, 1)          65        ['activation_27[0][0]']
#
# ==================================================================================================
# Total params: 31055297 (118.47 MB)
# Trainable params: 31043521 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________
